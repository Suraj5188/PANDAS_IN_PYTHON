# %% [markdown]
# <a href="https://colab.research.google.com/github/Suraj5188/PANDAS_IN_PYTHON/blob/main/Pandas_DataFrame_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Pyhton pandas some important functions***

# %%
import pandas as pd
import numpy as np

df=pd.read_csv("/content/drive/MyDrive/Demo_DATA_csv_files/Book wwc22 final version.csv")

# %%
print(df)
# Out:
#     Match_id        Team_1        Team_2                       Venue  \
# 0          1   New Zealand   West Indies   Bay Oval, Mount Maunganui
# 1          2    Bangladesh  South Africa    University Oval, Dunedin
# 2          3     Australia       England       Seddon Park, Hamilton
# 3          4      Pakistan         India   Bay Oval, Mount Maunganui
# 4          5   New Zealand    Bangladesh    University Oval, Dunedin
# 5          6     Australia      Pakistan   Bay Oval, Mount Maunganui
# 6          7   West Indies       England    University Oval, Dunedin
# 7          8   New Zealand         India       Seddon Park, Hamilton
# 8          9      Pakistan  South Africa   Bay Oval, Mount Maunganui
# 9         10   West Indies         India       Seddon Park, Hamilton
# 10        11   New Zealand     Australia   Basin Reserve, Wellington
# 11        12      Pakistan    Bangladesh       Seddon Park, Hamilton
# 12        13  South Africa       England   Bay Oval, Mount Maunganui
# ...

# %%
df.head()
# Out:
#    Match_id       Team_1        Team_2                      Venue  Stage  \
# 0         1  New Zealand   West Indies  Bay Oval, Mount Maunganui  Group
# 1         2   Bangladesh  South Africa   University Oval, Dunedin  Group
# 2         3    Australia       England      Seddon Park, Hamilton  Group
# 3         4     Pakistan         India  Bay Oval, Mount Maunganui  Group
# 4         5  New Zealand    Bangladesh   University Oval, Dunedin  Group
#
#    Toss_winner Toss_decision  First_innings_score  First_innings_wkts  \
# 0  New Zealand         Field                  259                   9
# 1   Bangladesh         Field                  207                  10
# 2      England         Field                  310                   3
# 3        India           Bat                  244                   7
# 4  New Zealand         Field                  140                   8
#
#    Second_innings_score  Second_innings_wkts        Winner Player_of_the_match
# ...

# %%
df.tail()
# Out:
#     Match_id     Team_1        Team_2                       Venue       Stage  \
# 26        27    England    Bangladesh   Basin Reserve, Wellington       Group
# 27        28      India  South Africa  Hagley Oval , Christchurch       Group
# 28        29  Australia   West Indies   Basin Reserve, Wellington  Semi Final
# 29        30    England  South Africa  Hagley Oval , Christchurch  Semi Final
# 30        31  Australia       England  Hagley Oval , Christchurch       Final
#
#      Toss_winner Toss_decision  First_innings_score  First_innings_wkts  \
# 26       England           Bat                  234                   6
# 27         India           Bat                  274                   7
# 28   West Indies         Field                  305                   3
# 29  South Africa         Field                  293                   8
# 30       England         Field                  356                   5
#
#     Second_innings_score  Second_innings_wkts        Winner  \
# ...

# %%
df.describe()
# Out:
#         Match_id  First_innings_score  First_innings_wkts  \
# count  31.000000            31.000000           31.000000
# mean   16.000000           220.741935            7.451613
# std     9.092121            72.708077            2.046765
# min     1.000000            61.000000            3.000000
# 25%     8.500000           165.000000            6.000000
# 50%    16.000000           234.000000            8.000000
# 75%    23.500000           270.000000            9.000000
# max    31.000000           356.000000           10.000000
#
#        Second_innings_score  Second_innings_wkts
# count             30.000000            30.000000
# mean             187.333333             7.566667
# std               59.716764             3.092631
# min               90.000000             1.000000
# 25%              136.000000             5.250000
# 50%              184.000000             9.000000
# 75%              228.000000            10.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Match_id              31 non-null     int64
#  1   Team_1                31 non-null     object
#  2   Team_2                31 non-null     object
#  3                Venue    31 non-null     object
#  4   Stage                 31 non-null     object
#  5   Toss_winner           31 non-null     object
#  6   Toss_decision         31 non-null     object
#  7   First_innings_score   31 non-null     int64
#  8   First_innings_wkts    31 non-null     int64
#  9   Second_innings_score  30 non-null     float64
#  10  Second_innings_wkts   30 non-null     float64
#  11  Winner                31 non-null     object
#  12  Player_of_the_match   30 non-null     object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 3.3+ KB

# %%
df.head()
# Out:
#    Match_id       Team_1        Team_2                      Venue  Stage  \
# 0         1  New Zealand   West Indies  Bay Oval, Mount Maunganui  Group
# 1         2   Bangladesh  South Africa   University Oval, Dunedin  Group
# 2         3    Australia       England      Seddon Park, Hamilton  Group
# 3         4     Pakistan         India  Bay Oval, Mount Maunganui  Group
# 4         5  New Zealand    Bangladesh   University Oval, Dunedin  Group
#
#    Toss_winner Toss_decision  First_innings_score  First_innings_wkts  \
# 0  New Zealand         Field                  259                   9
# 1   Bangladesh         Field                  207                  10
# 2      England         Field                  310                   3
# 3        India           Bat                  244                   7
# 4  New Zealand         Field                  140                   8
#
#    Second_innings_score  Second_innings_wkts        Winner Player_of_the_match
# ...

# %% [markdown]
# # ***1. dtype***

# %%
df['Winner'].dtypes
# Out:
# dtype('O')

# %%
df['Second_innings_wkts'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# # ***2.df.shape & df.size***

# %% [markdown]
# df.shape:<br>
# The DataFrame.shape returns a tuple of array dimensions representing the shape of a given DataFrame.

# %%
print(df.shape)
# Out:
# (31, 13)

# %% [markdown]
# df.size:<br>
# Return the number of rows if Series. Otherwise return the number of rows times number of columns if DataFrame.

# %%
#rows*column ex-(2(rows)*2(columns))
print(df.size)
# Out:
# 403

# %%
#simple Example
df2= pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
df2
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
df2.size
# Out:
# 4

# %% [markdown]
# # ***pandas.DataFrame.index***

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %% [markdown]
# # **pandas.DataFrame.dtypes**

# %%
print(df)
# Out:
#     Match_id        Team_1        Team_2                       Venue  \
# 0          1   New Zealand   West Indies   Bay Oval, Mount Maunganui
# 1          2    Bangladesh  South Africa    University Oval, Dunedin
# 2          3     Australia       England       Seddon Park, Hamilton
# 3          4      Pakistan         India   Bay Oval, Mount Maunganui
# 4          5   New Zealand    Bangladesh    University Oval, Dunedin
# 5          6     Australia      Pakistan   Bay Oval, Mount Maunganui
# 6          7   West Indies       England    University Oval, Dunedin
# 7          8   New Zealand         India       Seddon Park, Hamilton
# 8          9      Pakistan  South Africa   Bay Oval, Mount Maunganui
# 9         10   West Indies         India       Seddon Park, Hamilton
# 10        11   New Zealand     Australia   Basin Reserve, Wellington
# 11        12      Pakistan    Bangladesh       Seddon Park, Hamilton
# 12        13  South Africa       England   Bay Oval, Mount Maunganui
# ...

# %%
df.dtypes
# Out:
# Match_id                  int64
# Team_1                   object
# Team_2                   object
#              Venue       object
# Stage                    object
# Toss_winner              object
# Toss_decision            object
# First_innings_score       int64
# First_innings_wkts        int64
# Second_innings_score    float64
# Second_innings_wkts     float64
# Winner                   object
# Player_of_the_match      object
# dtype: object

# %% [markdown]
# # **pandas.DataFrame.select_dtypes  :**<br>
# DataFrame.select_dtypes(include=None, exclude=None)[source]
# Return a subset of the DataFrame’s columns based on the column dtypes.

# %%
df.select_dtypes(include='int64')
# Out:
#     Match_id  First_innings_score  First_innings_wkts
# 0          1                  259                   9
# 1          2                  207                  10
# 2          3                  310                   3
# 3          4                  244                   7
# 4          5                  140                   8
# 5          6                  190                   6
# 6          7                  225                   6
# 7          8                  260                   9
# 8          9                  223                   9
# 9         10                  317                   8
# 10        11                  269                   8
# 11        12                  234                   7
# 12        13                  235                   9
# 13        14                  131                  10
# 14        15                  134                  10
# 15        16                  228                  10
# ...

# %%
df.select_dtypes(include='float64')
# Out:
#     Second_innings_score  Second_innings_wkts
# 0                  256.0                 10.0
# 1                  175.0                 10.0
# 2                  298.0                  8.0
# 3                  137.0                 10.0
# 4                  144.0                  1.0
# 5                  193.0                  3.0
# 6                  218.0                 10.0
# 7                  198.0                 10.0
# 8                  217.0                 10.0
# 9                  162.0                 10.0
# 10                 128.0                 10.0
# 11                 225.0                  9.0
# 12                 236.0                  7.0
# 13                 132.0                  3.0
# 14                 136.0                  6.0
# 15                 229.0                  8.0
# 16                 136.0                 10.0
# 17                 280.0                  4.0
# 18                 204.0                  9.0
# ...

# %%
df.select_dtypes(include='object')
# Out:
#           Team_1        Team_2                       Venue       Stage  \
# 0    New Zealand   West Indies   Bay Oval, Mount Maunganui       Group
# 1     Bangladesh  South Africa    University Oval, Dunedin       Group
# 2      Australia       England       Seddon Park, Hamilton       Group
# 3       Pakistan         India   Bay Oval, Mount Maunganui       Group
# 4    New Zealand    Bangladesh    University Oval, Dunedin       Group
# 5      Australia      Pakistan   Bay Oval, Mount Maunganui       Group
# 6    West Indies       England    University Oval, Dunedin       Group
# 7    New Zealand         India       Seddon Park, Hamilton       Group
# 8       Pakistan  South Africa   Bay Oval, Mount Maunganui       Group
# 9    West Indies         India       Seddon Park, Hamilton       Group
# 10   New Zealand     Australia   Basin Reserve, Wellington       Group
# 11      Pakistan    Bangladesh       Seddon Park, Hamilton       Group
# ...

# %%
df.select_dtypes(exclude='float64')
# Out:
#     Match_id        Team_1        Team_2                       Venue  \
# 0          1   New Zealand   West Indies   Bay Oval, Mount Maunganui
# 1          2    Bangladesh  South Africa    University Oval, Dunedin
# 2          3     Australia       England       Seddon Park, Hamilton
# 3          4      Pakistan         India   Bay Oval, Mount Maunganui
# 4          5   New Zealand    Bangladesh    University Oval, Dunedin
# 5          6     Australia      Pakistan   Bay Oval, Mount Maunganui
# 6          7   West Indies       England    University Oval, Dunedin
# 7          8   New Zealand         India       Seddon Park, Hamilton
# 8          9      Pakistan  South Africa   Bay Oval, Mount Maunganui
# 9         10   West Indies         India       Seddon Park, Hamilton
# 10        11   New Zealand     Australia   Basin Reserve, Wellington
# 11        12      Pakistan    Bangladesh       Seddon Park, Hamilton
# 12        13  South Africa       England   Bay Oval, Mount Maunganui
# ...

# %% [markdown]
# # **pandas.DataFrame.values** :<br>
# property DataFrame.values
# Return a Numpy representation of the DataFrame.<br>
# Only the values in the DataFrame will be returned, the axes labels will be removed.

# %%
df.values
# Out:
# array([[1, 'New Zealand', 'West Indies', 'Bay Oval, Mount Maunganui',
#         'Group', 'New Zealand', 'Field', 259, 9, 256.0, 10.0,
#         'West Indies', 'Hayley Matthews'],
#        [2, 'Bangladesh', 'South Africa', 'University Oval, Dunedin',
#         'Group', 'Bangladesh', 'Field', 207, 10, 175.0, 10.0,
#         'South Africa', 'Ayabonga Khaka'],
#        [3, 'Australia', 'England', 'Seddon Park, Hamilton', 'Group',
#         'England', 'Field', 310, 3, 298.0, 8.0, 'Australia',
#         'Rachael Haynes'],
#        [4, 'Pakistan', 'India', 'Bay Oval, Mount Maunganui', 'Group',
#         'India', 'Bat', 244, 7, 137.0, 10.0, 'India', 'Pooja Vastrakar'],
#        [5, 'New Zealand', 'Bangladesh', 'University Oval, Dunedin',
#         'Group', 'New Zealand', 'Field', 140, 8, 144.0, 1.0,
#         'New Zealand', 'Suzie Bates'],
#        [6, 'Australia', 'Pakistan', 'Bay Oval, Mount Maunganui', 'Group',
#         'Australia', 'Field', 190, 6, 193.0, 3.0, 'Australia',
# ...

# %% [markdown]
# #**pandas.DataFrame.axes**<br>
# property DataFrame.axes[source]
# Return a list representing the axes of the DataFrame.
#
# It has the row axis labels and column axis labels as the only members. They are returned in that order.

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=31, step=1),
#  Index(['Match_id', 'Team_1', 'Team_2', '             Venue', 'Stage',
#         'Toss_winner', 'Toss_decision', 'First_innings_score',
#         'First_innings_wkts', 'Second_innings_score', 'Second_innings_wkts',
#         'Winner', 'Player_of_the_match'],
#        dtype='object')]

# %% [markdown]
# # **pandas.DataFrame.ndim :<br>**
# property DataFrame.ndim[source]
# Return an int representing the number of axes / array dimensions.
#
# Return 1 if Series. Otherwise return 2 if DataFrame.

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# # **pandas.DataFrame.memory_usage:<br>**
# DataFrame.memory_usage(index=True, deep=False)[source]
# Return the memory usage of each column in bytes.
#
# The memory usage can optionally include the contribution of the index and elements of object dtype.

# %%
df.memory_usage()
# Out:
# Index                   128
# Match_id                248
# Team_1                  248
# Team_2                  248
#              Venue      248
# Stage                   248
# Toss_winner             248
# Toss_decision           248
# First_innings_score     248
# First_innings_wkts      248
# Second_innings_score    248
# Second_innings_wkts     248
# Winner                  248
# Player_of_the_match     248
# dtype: int64

# %%
df.memory_usage(deep=False)
# Out:
# Index                   128
# Match_id                248
# Team_1                  248
# Team_2                  248
#              Venue      248
# Stage                   248
# Toss_winner             248
# Toss_decision           248
# First_innings_score     248
# First_innings_wkts      248
# Second_innings_score    248
# Second_innings_wkts     248
# Winner                  248
# Player_of_the_match     248
# dtype: int64

# %%
df.memory_usage(deep=True)
# Out:
# Index                    128
# Match_id                 248
# Team_1                  2056
# Team_2                  2044
#              Venue      2503
# Stage                   1932
# Toss_winner             2034
# Toss_decision           1906
# First_innings_score      248
# First_innings_wkts       248
# Second_innings_score     248
# Second_innings_wkts      248
# Winner                  2051
# Player_of_the_match     2135
# dtype: int64

# %% [markdown]
# #**pandas.DataFrame.empty: **<br>
# property DataFrame.empty[source]
# Indicator whether Series/DataFrame is empty.
#
# True if Series/DataFrame is entirely empty (no items), meaning any of the axes are of length 0.<br>
#
# Returns<br>
# bool<br>
# If Series/DataFrame is empty, return True, if not return False.
#
# See also

# %%
df.empty
# Out:
# False

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of     Match_id        Team_1        Team_2                       Venue  \
# 0          1   New Zealand   West Indies   Bay Oval, Mount Maunganui
# 1          2    Bangladesh  South Africa    University Oval, Dunedin
# 2          3     Australia       England       Seddon Park, Hamilton
# 3          4      Pakistan         India   Bay Oval, Mount Maunganui
# 4          5   New Zealand    Bangladesh    University Oval, Dunedin
# 5          6     Australia      Pakistan   Bay Oval, Mount Maunganui
# 6          7   West Indies       England    University Oval, Dunedin
# 7          8   New Zealand         India       Seddon Park, Hamilton
# 8          9      Pakistan  South Africa   Bay Oval, Mount Maunganui
# 9         10   West Indies         India       Seddon Park, Hamilton
# 10        11   New Zealand     Australia   Basin Reserve, Wellington
# 11        12      Pakistan    Bangladesh       Seddon Park, Hamilton
# ...

# %%
#If we only have NaNs in our DataFrame, it is not considered empty! We will need to drop the NaNs to make the DataFrame empty:
df.dropna().empty
# Out:
# False

# %%
df.isnull().sum()
# Out:
# Match_id                0
# Team_1                  0
# Team_2                  0
#              Venue      0
# Stage                   0
# Toss_winner             0
# Toss_decision           0
# First_innings_score     0
# First_innings_wkts      0
# Second_innings_score    1
# Second_innings_wkts     1
# Winner                  0
# Player_of_the_match     1
# dtype: int64
